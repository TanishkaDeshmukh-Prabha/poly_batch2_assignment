# %%
# Matplotlib – Day 1 Assignment
# Introduction to Matplotlib (Line Charts)

# Question 1
# Create your first line chart using the following data:
# ● X-axis: [1, 2, 3, 4, 5]
# ● Y-axis: [10, 20, 15, 25, 30]
# Display the chart.
# import matplotlib.pyplot as plt
# x=[1,2,3,4,5]
# y=[10,20,30,40,50]
# plt.plot()
# plt.show()

# %%
# Question 2
# Create a student marks line chart for five subjects.
# Marks:
# [72, 80, 76, 90, 95]
# Add:
# ● Chart Title
# ● X-axis Label
# ● Y-axis Label
# import matplotlib.pyplot as plt
# subjects=["English","Physics","Biology","Chemistry","Mathematics"]
# marks=[72,80,76,90,95]
# plt.plot(subjects,marks)
# plt.xlabel("Subjects")
# plt.ylabel("Marks")

# plt.show()

# %%
# Question 3
# Create an employee salary line chart using the following data:
# [25000, 32000, 40000, 38000, 45000]
# Requirements:
# ● Blue Line
# ● Circle (o) Marker
# ● Grid

# import matplotlib.pyplot as plt
# employees=["Madhura","Mansee","Tanishka","Arya","Priyanka"]
# salary=[25000, 32000, 40000, 38000, 45000]
# plt.plot(employees,salary,color="Blue",marker="o")
# plt.grid()
# plt.show()

# %%
# Question 4
# Plot the monthly sales for six months.
# Sales:
# [25000, 30000, 35000, 40000, 45000, 50000]
# Requirements:
# ● Green Line
# ● Dashed (--) Line Style
# ● Line Width = 3

# import matplotlib.pyplot as plt
# months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun"]
# sales = [25000, 30000, 35000, 40000, 45000, 50000]
# plt.plot(months, sales, color="green", linestyle="--", linewidth=3)
# plt.title("Monthly Sales")
# plt.xlabel("Months")
# plt.ylabel("Sales")

# plt.show()

# %%
# Question 5
# Create a line chart for the following temperature data:
# [30, 32, 31, 35, 36, 34, 33]
# Requirements:
# ● Star (*) Marker
# ● Red Line
# ● Chart Title
# import matplotlib.pyplot as plt
# Days=["Mon","Tue","Wed","Thu","Fri","Sat","Sun"]
# Temperature=[30,32,31,35,36,34,33]
# plt.title("Temperature Data")
# plt.plot(Days,Temperature,marker="*",color="red")
# plt.show()

# %%
Question 6
# Compare the marks of Student A and Student B on the same graph.
# Student A:
# [75, 80, 78, 90, 88]
# Student B:
# [70, 85, 80, 86, 92]
# Requirements:
# ● Different Colors
# ● Legend
# ● Grid
# import matplotlib.pyplot as plt

# subjects = ["English", "Maths", "Science", "Social", "Computer"]

# student_A = [75, 80, 78, 90, 88]
# student_B = [70, 85, 80, 86, 92]

# plt.plot(subjects, student_A, color="blue", label="Student A")
# plt.plot(subjects, student_B, color="red", label="Student B")

# plt.title("Comparison of Student A and Student B Marks")
# plt.xlabel("Subjects")
# plt.ylabel("Marks")

# plt.legend()
# plt.grid()

# plt.show()

# %%
# Question7
# Create an attendance chart for five days.
#Attendance:
# [40,42,39,45,44]
# Requirements:
# ● FigureSize(8,5)
# ● PurpleLine
# ● Diamond(D)Marker 
# ● X-axisLabel
# ● Y-axis Label

# import matplotlib.pyplot as plt
# days=["Mon","Tue","Wed","Thu","Fri"]
# attendance=[40,42,39,45,44]
# plt.plot(days,attendance,color="purple",marker="D",)
# plt.xlabel(Days)
# plt.ylabel(attendance)
# plt.title("Attendance Chart")
# plt.show()

# %%
# Question8
# Create a line chart showing product sales.
# SalesData:
# [120,180,160,220,250]
# Requirements:
# ●OrangeLine
# ●Dotted(:)LineStyle
# ●Circle(o)Marker
# ●Grid

# import matplotlib.pyplot as plt
# product=["Mobile","Tablet","Computer","Headphone","Airpods"]
# sales=[120,180,160,220,250]
# plt.plot(product,sales,color="orange",linestyle=":",marker="o")
# plt.grid()
# plt.show()

# %%
# Question9
# Create a line chart for website visitors over seven days.
# Visitors:
# [150,180,170,200,230,210,250]
# Requirements:
# ●FigureSize(10,5)
# ●BlackLine
# ●Plus(+)Marker
# ●Title
# ●Legend
# ●Grid
# import matplotlib.pyplot as plt
# days=[1,2,3,4,5,6,7]
# visitors=[150,180,170,200,230,210,250]
# plt.title("Visitors Data")
# plt.plot(days,visitors,color="black",marker="+")
# plt.figure(figsize=(10,5))
# plt.legend()

# plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_12924\147434516.py:18: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
# Question 10
# Create a professional Monthly Sales Report.
# Months:
# ["Jan", "Feb", "Mar", "Apr", "May", "Jun"]
# Sales:
# [25000, 30000, 28000, 40000, 45000, 50000]
# Requirements:
# ● Figure Size (10,5)
# ● Green Line
# ● Circle (o) Marker
# ● Dashed (--) Line Style
# ● Line Width = 3
# ● Chart Title
# ● X-axis Label
# ● Y-axis Label
# ● Grid
# ● Legend

# import matplotlib.pyplot as plt
# months=["Jan", "Feb", "Mar", "Apr", "May", "Jun"]
# sales=[25000, 30000, 28000, 40000, 45000, 50000]

# plt.figure(figsize=(10,5))

# plt.plot(months,sales,label="Monthly Sales Report",color="green",marker="o",linestyle="--",linewidth=3)
# plt.title("Monthly Sales Report")
# plt.xlabel("Months")
# plt.ylabel("Sales")
# plt.grid()
# plt.legend()

# plt.show()
