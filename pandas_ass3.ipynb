# %%
#Day 3 Assignment
#Data Cleaning

# Create a Student DataFrame containing:
# ● Missing values in Age and Marks columns.
# ● One duplicate student record.
# Perform the following operations:
# 1. Find missing values.
# 2. Count missing values.
# 3. Replace missing values with 0.
# 4. Replace missing age with average age.
# 5. Identify duplicate records.
# 6. Remove duplicate records.


import pandas as pd

# Create Student DataFrame
data = {
    "Student_ID": [1, 2, 3, 4, 4],
    "Name": ["Tanishka", "Priyanka", "Rajeshwari", "Snehal", "Snehal"],
    "Age": [20, None, 22, 21, 21],
    "Marks": [85, 90, None, 88, 88]
}

df = pd.DataFrame(data)

print("Original DataFrame")
print(df)
# print(df.isnull())
# print(df.isnull().sum())
# df_zero = df.fillna(0)

# print("After Replacing Missing Values with 0")
# print(df_zero)

# avg_age = df["Age"].mean()

# df["Age"] = df["Age"].fillna(avg_age)

# print("After Replacing Missing Age with Average Age")
# print(df)

# print(df.duplicated())

# df_no_duplicates = df.drop_duplicates()

# print("After Removing Duplicates")
# print(df_no_duplicates)
# Out:
# Original DataFrame
#    Student_ID        Name   Age  Marks
# 0           1    Tanishka  20.0   85.0
# 1           2    Priyanka   NaN   90.0
# 2           3  Rajeshwari  22.0    NaN
# 3           4      Snehal  21.0   88.0
# 4           4      Snehal  21.0   88.0
# After Removing Duplicates
#    Student_ID        Name   Age  Marks
# 0           1    Tanishka  20.0   85.0
# 1           2    Priyanka   NaN   90.0
# 2           3  Rajeshwari  22.0    NaN
# 3           4      Snehal  21.0   88.0
