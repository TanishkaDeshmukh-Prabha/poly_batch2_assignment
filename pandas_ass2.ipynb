# %%
#Day 2 Assignment
#Data Selection & Filtering

# Create an Employee DataFrame containing:
# ● Employee ID
# ● Name
# ● Department
# ● Salary
# ● City

# import pandas as pd
# employee={
#     "Employee Id":[101,102,103,104,105],
#     "Name":["Tanishka","Arya","Mansi","Priyanka","Madhura"],
#     "Department":["IT","HR","Sales","Manager","Accountant"],
#     "Salary":[100000,200000,10000,20000,300000],
#     "City":["Pune","Mumbai","Nashik","Nagpur","Aurangabad"]
# }
# df =pd .DataFrame(employee)
# print("Employee DataFrame")
# print(df)
# # df.head(3)
# # df.tail(2)
# # df.shape
# # df.columns
# # (df[df["Salary"]>40000])
# # (df[df["City"]=="Pune"])
# Out:
# Employee DataFrame
#    Employee Id      Name  Department  Salary        City
# 0          101  Tanishka          IT  100000        Pune
# 1          102      Arya          HR  200000      Mumbai
# 2          103     Mansi       Sales   10000      Nashik
# 3          104  Priyanka     Manager   20000      Nagpur
# 4          105   Madhura  Accountant  300000  Aurangabad
#    Employee Id      Name Department  Salary  City
# 0          101  Tanishka         IT  100000  Pune
