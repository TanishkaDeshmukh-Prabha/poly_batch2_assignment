# %%
# Pandas Practical Assignment
# 1.
# Create a DataFrame containing the following columns:
# ● Name
# ● Age
# ● City
# ● Marks
# Add data for 5 students.

# import pandas as pd
# data={
#     "Name":["Tanishka","Jango","Arya","Priyanka","Mansi"],
#     "Age":[18,17,19,18,17],
#     "City":["Pune","Delhi","Mumbai","Pune","Nashik"],
#     "Marks":[77,80,90,83,94]
# }

# 2.
# Display the complete DataFrame.
# import pandas as pd
# data={
#      "Name":["Tanishka","Jango","Arya","Priyanka","Mansi"],
#      "Age":[18,17,19,18,17],
#       "City":["Pune","Delhi","Mumbai","Pune","Nashik"],
#       "Marks":[77,80,90,83,94]
# }
# df=pd.DataFrame(data)
# print(df)

# 3.
# Display the first 3 rows using head().
# import pandas as pd
# data={
#      "Name":["Tanishka","Jango","Arya","Priyanka","Mansi"],
#      "Age":[18,17,19,18,17],
#       "City":["Pune","Delhi","Mumbai","Pune","Nashik"],
#       "Marks":[77,80,90,83,94]
# }
# df=pd.DataFrame(data)
# print(df)
# df.head(3)

# 4.
# Display the last 2 rows using tail().
# import pandas as pd
# data={
#      "Name":["Tanishka","Jango","Arya","Priyanka","Mansi"],
#      "Age":[18,17,19,18,17],
#       "City":["Pune","Delhi","Mumbai","Pune","Nashik"],
#       "Marks":[77,80,90,83,94]
# }
# df=pd.DataFrame(data)
# print(df)
# df.tail(2)

# 5.
# Display the shape of the DataFrame
# import pandas as pd
# data={
#      "Name":["Tanishka","Jango","Arya","Priyanka","Mansi"],
#      "Age":[18,17,19,18,17],
#       "City":["Pune","Delhi","Mumbai","Pune","Nashik"],
#       "Marks":[77,80,90,83,94]
# }
# df=pd.DataFrame(data)
# print(df)
# df.shape


# 6.
# Display all column names
# import pandas as pd
# data={
#      "Name":["Tanishka","Jango","Arya","Priyanka","Mansi"],
#      "Age":[18,17,19,18,17],
#       "City":["Pune","Delhi","Mumbai","Pune","Nashik"],
#       "Marks":[77,80,90,83,94]
# }
# df=pd.DataFrame(data)
# print(df)
# df.columns


# 7.
# Display Dataset Information using info()
# import pandas as pd
# data={
#      "Name":["Tanishka","Jango","Arya","Priyanka","Mansi"],
#      "Age":[18,17,19,18,17],
#       "City":["Pune","Delhi","Mumbai","Pune","Nashik"],
#       "Marks":[77,80,90,83,94]
# }
# df=pd.DataFrame(data)
# print(df)
# df.info()


# 8.
# Display Statistical  summary using describe().
# import pandas as pd
# data={
#      "Name":["Tanishka","Jango","Arya","Priyanka","Mansi"],
#      "Age":[18,17,19,18,17],
#       "City":["Pune","Delhi","Mumbai","Pune","Nashik"],
#       "Marks":[77,80,90,83,94]
# }
# df=pd.DataFrame(data)
# print(df)
# df.describe()


# 9.
# Read a CSV file named students.csv.
# import pandas as pd
# data={
#      "Name":["Tanishka","Jango","Arya","Priyanka","Mansi"],
#      "Age":[18,17,19,18,17],
#       "City":["Pune","Delhi","Mumbai","Pune","Nashik"],
#       "Marks":[77,80,90,83,94]
# }
# df=pd.DataFrame(data)
# print(df)
# df.to_csv("students.csv",index=False)
# print("\nCSV file saved successfully!!")


# 10.
# Save the DataFrame into a new CSV file named students_backup.csv
# import pandas as pd
# data={
#      "Name":["Tanishka","Jango","Arya","Priyanka","Mansi"],
#      "Age":[18,17,19,18,17],
#       "City":["Pune","Delhi","Mumbai","Pune","Nashik"],
#       "Marks":[77,80,90,83,94]
# }
# df=pd.DataFrame(data)
# print(df)
# df.to_csv("students.csv",index=False)
# print("\nCSV file saved successfully!!")

# new_df=pd.read_csv("students.csv")
# print("\nData Read From CSV:")
# print(new_df)


# 11.
# Display only the Name column.
# import pandas as pd
# data={
#      "Name":["Tanishka","Jango","Arya","Priyanka","Mansi"],
#      "Age":[18,17,19,18,17],
#      "City":["Pune","Delhi","Mumbai","Pune","Nashik"],
#      "Marks":[77,80,90,83,94]
# }
# df=pd.DataFrame(data)
# print(df)
# print(df["Name"])



# 12.
# Display Name and Marks columns
# import pandas as pd
# data={
#      "Name":["Tanishka","Jango","Arya","Priyanka","Mansi"],
#      "Age":[18,17,19,18,17],
#      "City":["Pune","Delhi","Mumbai","Pune","Nashik"],
#      "Marks":[77,80,90,83,94]
# }
# df=pd.DataFrame(data)
# print(df)
# print(df[["Name", "Marks"]])

# 13.
# Display students whose marks are greater than 80.
# import pandas as pd
# data={
#      "Name":["Tanishka","Jango","Arya","Priyanka","Mansi"],
#      "Age":[18,17,22,18,17],
#      "City":["Pune","Delhi","Mumbai","Pune","Nashik"],
#      "Marks":[77,80,90,83,94]
# }
# df=pd.DataFrame(data)
# print(df)
# (df[df["Marks"]>80])


# 14.
# Display students whose age is greater than 20.
# import pandas as pd
# data={
#     "Name":["Tanishka","Jango","Arya","Priyanka","Mansi"],
#      "Age":[18,17,22,18,17],
#      "City":["Pune","Delhi","Mumbai","Pune","Nashik"],
#      "Marks":[77,80,90,83,94]
# }
# df=pd.DataFrame(data)
# print(df)
# (df[df["Age"]>20])


# 15.
# Display Students who belong to Pune.
# import pandas as pd
# data={
#     "Name":["Tanishka","Jango","Arya","Priyanka","Mansi"],
#      "Age":[18,17,22,18,17],
#      "City":["Pune","Delhi","Mumbai","Pune","Nashik"],
#      "Marks":[77,80,90,83,94]
# }
# df=pd.DataFrame(data)
# print(df)
# (df[df["City"]=="Pune"])


# 16.
# Display students whose marks are between 70 and 90.
# import pandas as pd
# data={
#     "Name":["Tanishka","Jango","Arya","Priyanka","Mansi"],
#      "Age":[18,17,22,18,17],
#      "City":["Pune","Delhi","Mumbai","Pune","Nashik"],
#      "Marks":[77,80,90,83,94]
# }
# df=pd.DataFrame(data)
# print(df)
# (df[df["Marks"]>=70])
# (df[df["Marks"]<=90])


# 17.
# Display students whose city is Mumbai and marks are greater than 75.
# import pandas as pd
# data={
#     "Name":["Tanishka","Jango","Arya","Priyanka","Mansi"],
#      "Age":[18,17,22,18,17],
#      "City":["Pune","Delhi","Mumbai","Pune","Nashik"],
#      "Marks":[77,80,90,83,94]
# }
# df=pd.DataFrame(data)
# print(df)
# (df[df["Marks"]>75])
# (df[df["City"]=="Mumbai"])


# 18.
# Sort the DataFrame by Marks in ascending order
# import pandas as pd
# data={
#     "Name":["Tanishka","Jango","Arya","Priyanka","Mansi"],
#      "Age":[18,17,22,18,17],
#      "City":["Pune","Delhi","Mumbai","Pune","Nashik"],
#      "Marks":[77,80,90,83,94]
# }
# df=pd.DataFrame(data)
# print(df)
# df.sort_values("Marks")
# df.sort_values("Marks",ascending=True)


# 19.
# Sort the DataFrame by Marks in descending order.
# import pandas as pd
# data={
#     "Name":["Tanishka","Jango","Arya","Priyanka","Mansi"],
#      "Age":[18,17,22,18,17],
#      "City":["Pune","Delhi","Mumbai","Pune","Nashik"],
#      "Marks":[77,80,90,83,94]
# }
# df=pd.DataFrame(data)
# print(df)
# df.sort_values("Marks",descending=False)


# 20.
# Display all unique cities
# import pandas as pd
# data={
#     "Name":["Tanishka","Jango","Arya","Priyanka","Mansi"],
#      "Age":[18,17,22,18,17],
#      "City":["Pune","Delhi","Mumbai","Pune","Nashik"],
#      "Marks":[77,80,90,83,94]
# }
# df=pd.DataFrame(data)
# print(df)
# df["City"].unique()


# 21.
# Count the number of students in each city.
# import pandas as pd
# data={
#      "Name":["Tanishka","Jango","Arya","Priyanka","Mansi"],
#      "Age":[18,17,22,18,17],
#      "City":["Pune","Delhi","Mumbai","Pune","Nashik"],
#      "Marks":[77,80,90,83,94]
# }
# df=pd.DataFrame(data)
# print(df)
# print(df["City"].value_counts())


# 22.
# Display duplicate records
# import pandas as pd
# data={
#      "Name":["Tanishka","Jango","Arya","Priyanka","Mansi"],
#      "Age":[18,17,22,18,17],
#      "City":["Pune","Delhi","Mumbai","Pune","Nashik"],
#      "Marks":[77,80,90,83,94]
# }
# df=pd.DataFrame(data)
# print(df)
# print(df[df.duplicated()])


# 23.
# Remove duplicate records.
# import pandas as pd
# data={
#      "Name":["Tanishka","Jango","Arya","Priyanka","Mansi"],
#      "Age":[18,17,22,18,17],
#      "City":["Pune","Delhi","Mumbai","Pune","Nashik"],
#      "Marks":[77,80,90,83,94]
# }
# df=pd.DataFrame(data)
# df = df.drop_duplicates()
# print(df)


# 24.
# Check whether the dataset contains missing values.
# import pandas as pd
# data={
#      "Name":["Tanishka","Jango","Arya","Priyanka","Mansi"],
#      "Age":[18,17,22,18,17],
#      "City":["Pune","Delhi","Mumbai","Pune","Nashik"],
#      "Marks":[77,80,90,83,94]
# }
# df=pd.DataFrame(data)
# print(df)
# print(df.isnull())


# 25.
# Count missing values in each column
# import pandas as pd
# data={
#     "Name":["Tanishka","Jango","Arya","Priyanka","Mansi"],
#     "Age":[18,17,22,18,17],
#     "City":["Pune","Delhi","Mumbai","Pune","Nashik"],
#     "Marks":[77,80,90,83,94]
# }
# print(df.isnull().sum())
# Out:
# Name     0
# Age      0
# City     0
# Marks    0
# dtype: int64
