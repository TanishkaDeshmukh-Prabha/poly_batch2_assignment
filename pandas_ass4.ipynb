# %%
# import pandas as pd
# Perform the following operations:
# 1. Sort salary in ascending order.
# 2. Sort salary in descending order.
# 3. Display unique departments.
# 4. Count employees in each department.
# 5. Find average salary of each department.
# 6. Find maximum salary of each department.

# employee={     
#     "employees":["Tanishka","arya","mansi","Priyanka","Madhura"],
#     "Salary":[100000,50000,100000,20000,100000],
#     "Department":["IT","HR","IT","Accountant","IT"],
# }
# df=pd.DataFrame(employee)
# print(df)
#sort_values()

#sort(Ascending nd Descending):
# df.sort_values("Salary",ascending=False)
#df.sort_values("Salary",descending=False)

#Display unique departments.
#unique()
# df["Department"].unique()

# Count employees in each department.
#count()
# df.groupby("Department")["employees"].count()

#Find average salary of each department.
#mean()
#df.groupby("Department")["Salary"].mean()

#Find maximum salary of each department.
#max()
#df.groupby("Department")["Salary"].max()
# Out:
#   employees  Salary  Department
# 0  Tanishka  100000          IT
# 1      arya   50000          HR
# 2     mansi  100000          IT
# 3  Priyanka   20000  Accountant
# 4   Madhura  100000          IT
# employees
# Tanishka    1
# arya        1
# mansi       1
# Priyanka    1
# Madhura     1
# Name: count, dtype: int64
