# %%
#Day-1 (Pandas Assignment)
#Create a pandas DataFrame for 5 Students containing 

#Q1. Name,2.Age,3.City,4.Marks
# import pandas as pd
# student={
#     "Name":["Tanishka","Jango","Arya","Mansi","Priyanka"],
#     "Age":[20,18,17,15,12],
#     "City":["pune","mumbai","nashik","Delhi","Nagpur"],
#     "Marks":[80,50,40,60,75]
# }
# df=pd.DataFrame(student)
# print(df)

# df.to_csv("students.csv",index=False)
# print("\nCSV file saved successfully!!")

# new_df=pd.read_csv("students.csv")
# print("\nData Read From CSV:")
# print(new_df)

# %%
#Q2.write a program to create a DataFrame from a Dictionary
# import pandas as pd
# data={
#     "Name":["Tanishka","Jango","Priyanka"],
#     "Age":[18,8,17]
#            }
# df=pd.DataFrame(data)
# print(df)
# Out:
#        Name  Age
# 0  Tanishka   18
# 1     Jango    8
# 2  Priyanka   17
